# %%
# !wget https://github.com/garythung/trashnet/raw/master/data/dataset-resized.zip
# Out:
# --2019-12-31 17:36:01--  https://github.com/garythung/trashnet/raw/master/data/dataset-resized.zip
# Resolving github.com (github.com)... 140.82.118.3
# Connecting to github.com (github.com)|140.82.118.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/garythung/trashnet/master/data/dataset-resized.zip [following]
# --2019-12-31 17:36:01--  https://raw.githubusercontent.com/garythung/trashnet/master/data/dataset-resized.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42834870 (41M) [application/zip]
# Saving to: ‘dataset-resized.zip’
#
# dataset-resized.zip 100%[===================>]  40.85M   174MB/s    in 0.2s
#
# 2019-12-31 17:36:03 (174 MB/s) - ‘dataset-resized.zip’ saved [42834870/42834870]

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %config InlineBackend.figure_format = 'retina'

# %%
from fastai.vision import *
from fastai.metrics import error_rate
from pathlib import Path
from glob2 import glob
from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np
import os
import zipfile as zf
import shutil
import re
import seaborn as sns

# %%
files = zf.ZipFile("dataset-resized.zip",'r')
files.extractall()
files.close()

# %%
os.listdir(os.path.join(os.getcwd(),"dataset-resized"))
# Out:
# ['trash', 'glass', 'paper', 'cardboard', 'metal', '.DS_Store', 'plastic']

# %%
## helper functions ##

## splits indices for a folder into train, validation, and test indices with random sampling
    ## input: folder path
    ## output: train, valid, and test indices    
def split_indices(folder,seed1,seed2):    
    n = len(os.listdir(folder))
    full_set = list(range(1,n+1))

    ## train indices
    random.seed(seed1)
    train = random.sample(list(range(1,n+1)),int(.5*n))

    ## temp
    remain = list(set(full_set)-set(train))

    ## separate remaining into validation and test
    random.seed(seed2)
    valid = random.sample(remain,int(.5*len(remain)))
    test = list(set(remain)-set(valid))
    
    return(train,valid,test)

## gets file names for a particular type of trash, given indices
    ## input: waste category and indices
    ## output: file names 
def get_names(waste_type,indices):
    file_names = [waste_type+str(i)+".jpg" for i in indices]
    return(file_names)    

## moves group of source files to another folder
    ## input: list of source files and destination folder
    ## no output
def move_files(source_files,destination_folder):
    for file in source_files:
        shutil.move(file,destination_folder)

# %%
## paths will be train/cardboard, train/glass, etc...
subsets = ['train','valid']
waste_types = ['cardboard','glass','metal','paper','plastic','trash']

## create destination folders for data subset and waste type
for subset in subsets:
    for waste_type in waste_types:
        folder = os.path.join('data',subset,waste_type)
        if not os.path.exists(folder):
            os.makedirs(folder)
            
if not os.path.exists(os.path.join('data','test')):
    os.makedirs(os.path.join('data','test'))
            
## move files to destination folders for each waste type
for waste_type in waste_types:
    source_folder = os.path.join('dataset-resized',waste_type)
    train_ind, valid_ind, test_ind = split_indices(source_folder,1,1)
    
    ## move source files to train
    train_names = get_names(waste_type,train_ind)
    train_source_files = [os.path.join(source_folder,name) for name in train_names]
    train_dest = "data/train/"+waste_type
    move_files(train_source_files,train_dest)
    
    ## move source files to valid
    valid_names = get_names(waste_type,valid_ind)
    valid_source_files = [os.path.join(source_folder,name) for name in valid_names]
    valid_dest = "data/valid/"+waste_type
    move_files(valid_source_files,valid_dest)
    
    ## move source files to test
    test_names = get_names(waste_type,test_ind)
    test_source_files = [os.path.join(source_folder,name) for name in test_names]
    ## I use data/test here because the images can be mixed up
    move_files(test_source_files,"data/test")

# %%
## get a path to the folder with images
path = Path(os.getcwd())/"data"
path
# Out:
# PosixPath('/content/data')

# %%
## apply transformations to data
tfms = get_transforms(do_flip=True,flip_vert=True)
data = ImageDataBunch.from_folder(path,test="test",ds_tfms=tfms,bs=16)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (1262 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# trash,trash,trash,trash,trash
# Path: /content/data;
#
# Valid: LabelList (630 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# trash,trash,trash,trash,trash
# Path: /content/data;
#
# Test: LabelList (635 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: EmptyLabelList
# ,,,,
# Path: /content/data

# %%
data.show_batch(rows=4,figsize=(10,8))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
learn = create_cnn(data,models.vgg16_bn,metrics=error_rate,callback_fns=ShowGraph)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:106: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/checkpoints/vgg16_bn-6c64b313.pth
# 100%|██████████| 528M/528M [00:09<00:00, 55.7MB/s]

# %%
learn.lr_find(start_lr=1e-6,end_lr=1e1)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(20,max_lr=5.13e-03)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.637131</td>
#       <td>0.658303</td>
#       <td>0.241270</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.055011</td>
#       <td>0.527420</td>
#       <td>0.190476</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.912142</td>
#       <td>0.536348</td>
#       <td>0.177778</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.822689</td>
#       <td>0.430422</td>
#       <td>0.150794</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.822929</td>
#       <td>0.627643</td>
#       <td>0.206349</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.794560</td>
#       <td>0.739380</td>
#       <td>0.203175</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.785699</td>
#       <td>1.219319</td>
#       <td>0.295238</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.691930</td>
#       <td>0.593053</td>
#       <td>0.174603</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.768504</td>
#       <td>0.460194</td>
#       <td>0.144444</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.627995</td>
#       <td>0.546412</td>
#       <td>0.165079</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.551049</td>
#       <td>0.379393</td>
#       <td>0.120635</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.495115</td>
#       <td>0.318613</td>
#       <td>0.100000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.449850</td>
#       <td>0.336954</td>
#       <td>0.107937</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.365471</td>
#       <td>0.228397</td>
#       <td>0.071429</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.348176</td>
#       <td>0.236785</td>
#       <td>0.071429</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.292255</td>
#       <td>0.210082</td>
#       <td>0.073016</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.270360</td>
#       <td>0.211237</td>
#       <td>0.065079</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.250223</td>
#       <td>0.209753</td>
#       <td>0.069841</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.223625</td>
#       <td>0.191768</td>
#       <td>0.065079</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.232810</td>
#       <td>0.196213</td>
#       <td>0.071429</td>
#       <td>00:39</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L163" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>False</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>alpha</code></strong>:<code>float</code>=<strong><em><code>0.6</code></em></strong>, <strong><code>cmap</code></strong>:<code>str</code>=<strong><em><code>'magma'</code></em></strong>, <strong><code>show_text</code></strong>:<code>bool</code>=<strong><em><code>True</code></em></strong>, <strong><code>return_fig</code></strong>:<code>bool</code>=<strong><em><code>None</code></em></strong>) → <code>Optional</code>[<code>Figure</code>]</p>
# </blockquote>
# <div class="collapse" id="_cl_int_plot_top_losses-pytest"><div class="card card-body pytest_card"><a type="button" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" class="close" aria-label="Close"><span aria-hidden="true">&times;</span></a><p>No tests found for <code>_cl_int_plot_top_losses</code>. To contribute a test please refer to <a href="/dev/test.html">this guide</a> and <a href="https://forums.fast.ai/t/improving-expanding-functional-tests/32929">this discussion</a>.</p></div></div><p>Show images in <code>top_losses</code> along with their prediction, actual, loss, and probability of actual class.</p>
# <p><a href="https://docs.fast.ai/vision.learner.html#_cl_int_plot_top_losses" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
interp.most_confused(min_val=2)
# Out:
# [('glass', 'metal', 8),
#  ('plastic', 'metal', 7),
#  ('glass', 'plastic', 6),
#  ('plastic', 'glass', 3),
#  ('plastic', 'trash', 3),
#  ('cardboard', 'paper', 2),
#  ('paper', 'trash', 2),
#  ('plastic', 'paper', 2),
#  ('trash', 'cardboard', 2),
#  ('trash', 'plastic', 2)]

# %%
preds = learn.get_preds(ds_type=DatasetType.Test)

# %%
print(preds[0].shape)
preds[0]
# Out:
# torch.Size([635, 6])
# tensor([[6.6361e-06, 6.3346e-01, 3.2833e-01, 2.0773e-04, 3.7722e-02, 2.7707e-04],
#         [1.1343e-04, 1.3000e-06, 1.1119e-06, 9.9530e-01, 3.7103e-03, 8.7882e-04],
#         [6.5753e-03, 4.1233e-06, 1.8963e-04, 9.8989e-01, 8.8124e-05, 3.2484e-03],
#         ...,
#         [1.5686e-04, 6.6760e-01, 9.2172e-04, 1.0534e-04, 3.2988e-01, 1.3291e-03],
#         [1.0000e+00, 5.1839e-12, 2.2942e-12, 2.1119e-08, 1.7734e-08, 8.2118e-08],
#         [1.2486e-04, 3.3061e-07, 1.1918e-03, 9.6157e-01, 2.0374e-02, 1.6737e-02]])

# %%
max_idxs = np.asarray(np.argmax(preds[0],axis=1))

# %%
yhat = []
for max_idx in max_idxs:
    yhat.append(data.classes[max_idx])

# %%
yhat
# Out:
# ['glass',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'trash',
#  'glass',
#  'paper',
#  'trash',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'metal',
#  'cardboard',
#  'plastic',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'trash',
#  'glass',
#  'cardboard',
#  'trash',
#  'metal',
#  'cardboard',
#  'paper',
#  'trash',
#  'metal',
#  'metal',
#  'plastic',
#  'cardboard',
#  'glass',
#  'plastic',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'paper',
#  'trash',
#  'metal',
#  'glass',
#  'metal',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'glass',
#  'plastic',
#  'trash',
#  'metal',
#  'metal',
#  'paper',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'metal',
#  'plastic',
#  'glass',
#  'cardboard',
#  'metal',
#  'metal',
#  'cardboard',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'cardboard',
#  'metal',
#  'metal',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'metal',
#  'cardboard',
#  'trash',
#  'cardboard',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'metal',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'metal',
#  'plastic',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'trash',
#  'metal',
#  'metal',
#  'plastic',
#  'glass',
#  'cardboard',
#  'metal',
#  'metal',
#  'glass',
#  'metal',
#  'plastic',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'plastic',
#  'glass',
#  'metal',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'plastic',
#  'trash',
#  'paper',
#  'glass',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'metal',
#  'trash',
#  'cardboard',
#  'plastic',
#  'metal',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'glass',
#  'metal',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'trash',
#  'glass',
#  'paper',
#  'plastic',
#  'metal',
#  'glass',
#  'glass',
#  'plastic',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'metal',
#  'plastic',
#  'glass',
#  'paper',
#  'metal',
#  'cardboard',
#  'metal',
#  'paper',
#  'trash',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'glass',
#  'metal',
#  'cardboard',
#  'plastic',
#  'metal',
#  'trash',
#  'plastic',
#  'metal',
#  'paper',
#  'glass',
#  'metal',
#  'glass',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'glass',
#  'trash',
#  'trash',
#  'metal',
#  'glass',
#  'metal',
#  'paper',
#  'cardboard',
#  'trash',
#  'glass',
#  'plastic',
#  'cardboard',
#  'metal',
#  'plastic',
#  'metal',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'plastic',
#  'trash',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'glass',
#  'metal',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'plastic',
#  'glass',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'glass',
#  'trash',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'metal',
#  'glass',
#  'trash',
#  'metal',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'metal',
#  'metal',
#  'metal',
#  'trash',
#  'metal',
#  'glass',
#  'metal',
#  'trash',
#  'plastic',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'paper',
#  'glass',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'trash',
#  'plastic',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'trash',
#  'metal',
#  'trash',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'plastic',
#  'metal',
#  'cardboard',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'metal',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'trash',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'metal',
#  'metal',
#  'metal',
#  'metal',
#  'plastic',
#  'plastic',
#  'glass',
#  'trash',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'cardboard',
#  'glass',
#  'plastic',
#  'glass',
#  'metal',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'glass',
#  'metal',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'paper',
#  'metal',
#  'metal',
#  'glass',
#  'trash',
#  'glass',
#  'trash',
#  'metal',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'metal',
#  'trash',
#  'plastic',
#  'glass',
#  'paper',
#  'metal',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'trash',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'metal',
#  'glass',
#  'plastic',
#  'metal',
#  'glass',
#  'plastic',
#  'trash',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'glass',
#  'cardboard',
#  'trash',
#  'glass',
#  'plastic',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'plastic',
#  'paper',
#  'plastic',
#  'glass',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'trash',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'metal',
#  'plastic',
#  'paper',
#  'plastic',
#  'glass',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'trash',
#  'metal',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'cardboard',
#  'paper']

# %%
learn.data.test_ds[0][0]
# Out:
# Image (3, 384, 512)

# %%
y = []

## convert POSIX paths to string first
for label_path in data.test_ds.items:
    y.append(str(label_path))
    
## then extract waste type from file path
pattern = re.compile("([a-z]+)[0-9]+")
for i in range(len(y)):
    y[i] = pattern.search(y[i]).group(1)

# %%
## predicted values
print(yhat[0:5])
## actual values
print(y[0:5])
# Out:
# ['glass', 'paper', 'paper', 'plastic', 'paper']
# ['glass', 'paper', 'paper', 'plastic', 'paper']

# %%
cm = confusion_matrix(y,yhat)
print(cm)
# Out:
# [[ 98   0   2   0   1   0]
#  [  0 108  13   0   5   0]
#  [  0   4  98   0   0   1]
#  [  0   0   2 143   1   3]
#  [  0   3   3   0 112   3]
#  [  1   1   0   1   4  28]]

# %%
df_cm = pd.DataFrame(cm,waste_types,waste_types)

plt.figure(figsize=(10,8))
sns.heatmap(df_cm,annot=True,fmt="d",cmap="YlGnBu")

# %%
correct = 0

for r in range(len(cm)):
    for c in range(len(cm)):
        if (r==c):
            correct += cm[r,c]

# %%
accuracy = correct/sum(sum(cm))
accuracy
# Out:
# 0.9244094488188976
