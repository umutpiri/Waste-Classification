# %%
# !wget https://github.com/garythung/trashnet/raw/master/data/dataset-resized.zip
# Out:
# --2019-12-31 16:24:51--  https://github.com/garythung/trashnet/raw/master/data/dataset-resized.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/garythung/trashnet/master/data/dataset-resized.zip [following]
# --2019-12-31 16:24:56--  https://raw.githubusercontent.com/garythung/trashnet/master/data/dataset-resized.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42834870 (41M) [application/zip]
# Saving to: ‘dataset-resized.zip’
#
# dataset-resized.zip 100%[===================>]  40.85M   159MB/s    in 0.3s
#
# 2019-12-31 16:24:57 (159 MB/s) - ‘dataset-resized.zip’ saved [42834870/42834870]

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %config InlineBackend.figure_format = 'retina'

# %%
from fastai.vision import *
from fastai.metrics import error_rate
from pathlib import Path
from glob2 import glob
from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np
import os
import zipfile as zf
import shutil
import re
import seaborn as sns

from torchvision.models import googlenet

# %%
files = zf.ZipFile("dataset-resized.zip",'r')
files.extractall()
files.close()

# %%
os.listdir(os.path.join(os.getcwd(),"dataset-resized"))
# Out:
# ['trash', 'glass', 'paper', 'cardboard', 'metal', '.DS_Store', 'plastic']

# %%
## helper functions ##

## splits indices for a folder into train, validation, and test indices with random sampling
    ## input: folder path
    ## output: train, valid, and test indices    
def split_indices(folder,seed1,seed2):    
    n = len(os.listdir(folder))
    full_set = list(range(1,n+1))

    ## train indices
    random.seed(seed1)
    train = random.sample(list(range(1,n+1)),int(.5*n))

    ## temp
    remain = list(set(full_set)-set(train))

    ## separate remaining into validation and test
    random.seed(seed2)
    valid = random.sample(remain,int(.5*len(remain)))
    test = list(set(remain)-set(valid))
    
    return(train,valid,test)

## gets file names for a particular type of trash, given indices
    ## input: waste category and indices
    ## output: file names 
def get_names(waste_type,indices):
    file_names = [waste_type+str(i)+".jpg" for i in indices]
    return(file_names)    

## moves group of source files to another folder
    ## input: list of source files and destination folder
    ## no output
def move_files(source_files,destination_folder):
    for file in source_files:
        shutil.move(file,destination_folder)

# %%
## paths will be train/cardboard, train/glass, etc...
subsets = ['train','valid']
waste_types = ['cardboard','glass','metal','paper','plastic','trash']

## create destination folders for data subset and waste type
for subset in subsets:
    for waste_type in waste_types:
        folder = os.path.join('data',subset,waste_type)
        if not os.path.exists(folder):
            os.makedirs(folder)
            
if not os.path.exists(os.path.join('data','test')):
    os.makedirs(os.path.join('data','test'))
            
## move files to destination folders for each waste type
for waste_type in waste_types:
    source_folder = os.path.join('dataset-resized',waste_type)
    train_ind, valid_ind, test_ind = split_indices(source_folder,1,1)
    
    ## move source files to train
    train_names = get_names(waste_type,train_ind)
    train_source_files = [os.path.join(source_folder,name) for name in train_names]
    train_dest = "data/train/"+waste_type
    move_files(train_source_files,train_dest)
    
    ## move source files to valid
    valid_names = get_names(waste_type,valid_ind)
    valid_source_files = [os.path.join(source_folder,name) for name in valid_names]
    valid_dest = "data/valid/"+waste_type
    move_files(valid_source_files,valid_dest)
    
    ## move source files to test
    test_names = get_names(waste_type,test_ind)
    test_source_files = [os.path.join(source_folder,name) for name in test_names]
    ## I use data/test here because the images can be mixed up
    move_files(test_source_files,"data/test")

# %%
## get a path to the folder with images
path = Path(os.getcwd())/"data"
path
# Out:
# PosixPath('/content/data')

# %%
## apply transformations to data
tfms = get_transforms(do_flip=True,flip_vert=True)
data = ImageDataBunch.from_folder(path,test="test",ds_tfms=tfms,bs=16)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (1262 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# trash,trash,trash,trash,trash
# Path: /content/data;
#
# Valid: LabelList (630 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# trash,trash,trash,trash,trash
# Path: /content/data;
#
# Test: LabelList (635 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: EmptyLabelList
# ,,,,
# Path: /content/data

# %%
data.show_batch(rows=4,figsize=(10,8))

# %%
learn = create_cnn(data,googlenet,metrics=error_rate,callback_fns=ShowGraph)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:106: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/checkpoints/googlenet-1378be20.pth
# 100%|██████████| 49.7M/49.7M [00:03<00:00, 16.5MB/s]

# %%
learn.lr_find(start_lr=1e-6,end_lr=1e1)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(20,max_lr=5.13e-03)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.494128</td>
#       <td>0.632698</td>
#       <td>0.215873</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.012401</td>
#       <td>0.584604</td>
#       <td>0.200000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.912184</td>
#       <td>0.579531</td>
#       <td>0.188889</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.867099</td>
#       <td>0.552711</td>
#       <td>0.169841</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.787010</td>
#       <td>0.522552</td>
#       <td>0.171429</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.664281</td>
#       <td>0.486760</td>
#       <td>0.119048</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.636528</td>
#       <td>0.419915</td>
#       <td>0.120635</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.605729</td>
#       <td>0.416836</td>
#       <td>0.133333</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.584280</td>
#       <td>0.369540</td>
#       <td>0.114286</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.479003</td>
#       <td>0.307064</td>
#       <td>0.101587</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.501553</td>
#       <td>0.319706</td>
#       <td>0.100000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.412919</td>
#       <td>0.323068</td>
#       <td>0.082540</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.365358</td>
#       <td>0.293320</td>
#       <td>0.079365</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.309002</td>
#       <td>0.295353</td>
#       <td>0.092063</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.237953</td>
#       <td>0.229284</td>
#       <td>0.082540</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.208028</td>
#       <td>0.254002</td>
#       <td>0.077778</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.199905</td>
#       <td>0.235505</td>
#       <td>0.068254</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.186092</td>
#       <td>0.216255</td>
#       <td>0.063492</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.170675</td>
#       <td>0.208455</td>
#       <td>0.065079</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.152819</td>
#       <td>0.206719</td>
#       <td>0.063492</td>
#       <td>00:39</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L163" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>False</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>alpha</code></strong>:<code>float</code>=<strong><em><code>0.6</code></em></strong>, <strong><code>cmap</code></strong>:<code>str</code>=<strong><em><code>'magma'</code></em></strong>, <strong><code>show_text</code></strong>:<code>bool</code>=<strong><em><code>True</code></em></strong>, <strong><code>return_fig</code></strong>:<code>bool</code>=<strong><em><code>None</code></em></strong>) → <code>Optional</code>[<code>Figure</code>]</p>
# </blockquote>
# <div class="collapse" id="_cl_int_plot_top_losses-pytest"><div class="card card-body pytest_card"><a type="button" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" class="close" aria-label="Close"><span aria-hidden="true">&times;</span></a><p>No tests found for <code>_cl_int_plot_top_losses</code>. To contribute a test please refer to <a href="/dev/test.html">this guide</a> and <a href="https://forums.fast.ai/t/improving-expanding-functional-tests/32929">this discussion</a>.</p></div></div><p>Show images in <code>top_losses</code> along with their prediction, actual, loss, and probability of actual class.</p>
# <p><a href="https://docs.fast.ai/vision.learner.html#_cl_int_plot_top_losses" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %%
interp.most_confused(min_val=2)
# Out:
# [('cardboard', 'paper', 8),
#  ('glass', 'metal', 4),
#  ('glass', 'plastic', 4),
#  ('plastic', 'metal', 4),
#  ('plastic', 'paper', 3),
#  ('plastic', 'trash', 3),
#  ('paper', 'trash', 2),
#  ('plastic', 'glass', 2),
#  ('trash', 'cardboard', 2),
#  ('trash', 'paper', 2)]

# %%
preds = learn.get_preds(ds_type=DatasetType.Test)

# %%
print(preds[0].shape)
preds[0]
# Out:
# torch.Size([635, 6])
# tensor([[3.8672e-04, 9.1832e-01, 5.3457e-02, 3.4221e-05, 2.7791e-02, 9.6637e-06],
#         [1.2060e-07, 6.9580e-07, 1.7875e-09, 1.0000e+00, 1.9327e-06, 6.8399e-08],
#         [1.1524e-03, 2.4766e-06, 4.1935e-04, 9.9725e-01, 1.1079e-03, 6.6528e-05],
#         ...,
#         [2.4266e-04, 5.7291e-03, 9.5093e-03, 4.7929e-04, 9.8399e-01, 4.7505e-05],
#         [9.9999e-01, 7.9302e-08, 2.1133e-09, 7.2115e-06, 4.3071e-07, 7.6531e-07],
#         [1.7429e-06, 2.5895e-08, 7.2235e-07, 9.9966e-01, 5.6783e-05, 2.7599e-04]])

# %%
max_idxs = np.asarray(np.argmax(preds[0],axis=1))

# %%
yhat = []
for max_idx in max_idxs:
    yhat.append(data.classes[max_idx])

# %%
yhat
# Out:
# ['glass',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'trash',
#  'glass',
#  'paper',
#  'metal',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'trash',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'plastic',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'trash',
#  'glass',
#  'cardboard',
#  'trash',
#  'glass',
#  'cardboard',
#  'paper',
#  'trash',
#  'metal',
#  'metal',
#  'plastic',
#  'cardboard',
#  'glass',
#  'plastic',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'paper',
#  'trash',
#  'metal',
#  'glass',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'glass',
#  'plastic',
#  'trash',
#  'plastic',
#  'glass',
#  'paper',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'metal',
#  'plastic',
#  'glass',
#  'cardboard',
#  'metal',
#  'metal',
#  'cardboard',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'cardboard',
#  'metal',
#  'metal',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'metal',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'metal',
#  'plastic',
#  'plastic',
#  'plastic',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'trash',
#  'metal',
#  'metal',
#  'plastic',
#  'glass',
#  'cardboard',
#  'metal',
#  'metal',
#  'metal',
#  'plastic',
#  'plastic',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'trash',
#  'plastic',
#  'glass',
#  'metal',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'plastic',
#  'trash',
#  'paper',
#  'glass',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'metal',
#  'trash',
#  'plastic',
#  'metal',
#  'metal',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'paper',
#  'glass',
#  'metal',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'trash',
#  'glass',
#  'paper',
#  'plastic',
#  'metal',
#  'glass',
#  'glass',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'metal',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'metal',
#  'trash',
#  'trash',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'metal',
#  'trash',
#  'plastic',
#  'glass',
#  'paper',
#  'glass',
#  'metal',
#  'glass',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'glass',
#  'trash',
#  'trash',
#  'metal',
#  'plastic',
#  'glass',
#  'paper',
#  'cardboard',
#  'trash',
#  'glass',
#  'plastic',
#  'cardboard',
#  'metal',
#  'plastic',
#  'metal',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'plastic',
#  'plastic',
#  'glass',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'glass',
#  'metal',
#  'glass',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'plastic',
#  'glass',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'glass',
#  'trash',
#  'metal',
#  'metal',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'metal',
#  'glass',
#  'trash',
#  'metal',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'plastic',
#  'glass',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'glass',
#  'metal',
#  'trash',
#  'trash',
#  'metal',
#  'glass',
#  'metal',
#  'trash',
#  'plastic',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'trash',
#  'plastic',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'trash',
#  'metal',
#  'trash',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'plastic',
#  'metal',
#  'cardboard',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'metal',
#  'metal',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'trash',
#  'paper',
#  'paper',
#  'trash',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'glass',
#  'metal',
#  'plastic',
#  'paper',
#  'trash',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'metal',
#  'metal',
#  'metal',
#  'metal',
#  'plastic',
#  'plastic',
#  'glass',
#  'trash',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'metal',
#  'glass',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'cardboard',
#  'glass',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'metal',
#  'plastic',
#  'glass',
#  'plastic',
#  'plastic',
#  'paper',
#  'metal',
#  'metal',
#  'trash',
#  'trash',
#  'glass',
#  'trash',
#  'metal',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'metal',
#  'trash',
#  'plastic',
#  'plastic',
#  'paper',
#  'metal',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'trash',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'metal',
#  'glass',
#  'plastic',
#  'plastic',
#  'glass',
#  'plastic',
#  'trash',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'glass',
#  'cardboard',
#  'trash',
#  'metal',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'paper',
#  'glass',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'plastic',
#  'paper',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'plastic',
#  'trash',
#  'paper',
#  'cardboard',
#  'glass',
#  'glass',
#  'metal',
#  'plastic',
#  'paper',
#  'trash',
#  'glass',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'trash',
#  'metal',
#  'paper',
#  'plastic',
#  'glass',
#  'plastic',
#  'cardboard',
#  'paper']

# %%
learn.data.test_ds[0][0]
# Out:
# Image (3, 384, 512)

# %%
y = []

## convert POSIX paths to string first
for label_path in data.test_ds.items:
    y.append(str(label_path))
    
## then extract waste type from file path
pattern = re.compile("([a-z]+)[0-9]+")
for i in range(len(y)):
    y[i] = pattern.search(y[i]).group(1)

# %%
## predicted values
print(yhat[0:5])
## actual values
print(y[0:5])
# Out:
# ['glass', 'paper', 'paper', 'plastic', 'paper']
# ['glass', 'paper', 'paper', 'plastic', 'paper']

# %%
cm = confusion_matrix(y,yhat)
print(cm)
# Out:
# [[ 95   0   1   4   1   0]
#  [  0 109   7   0   9   1]
#  [  0   6  95   0   2   0]
#  [  0   0   1 142   0   6]
#  [  0   5   1   1 111   3]
#  [  0   0   0   2   3  30]]

# %%
df_cm = pd.DataFrame(cm,waste_types,waste_types)

plt.figure(figsize=(10,8))
sns.heatmap(df_cm,annot=True,fmt="d",cmap="YlGnBu")

# %%
correct = 0

for r in range(len(cm)):
    for c in range(len(cm)):
        if (r==c):
            correct += cm[r,c]

# %%
accuracy = correct/sum(sum(cm))
accuracy
# Out:
# 0.9165354330708662
